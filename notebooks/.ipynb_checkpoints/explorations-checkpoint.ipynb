# %% [markdown]
# Note book to explore solutions.

# %%
import pandas as pd

data = [100, 102, 114]

series = pd.Series(data)

print(series)
# Out:
# 0    100
# 1    102
# 2    114
# dtype: int64

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/movies_data_1.csv")
#df.head(10)

df.info()

df.describe(include='all')

df.shape

df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10147 entries, 0 to 10146
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MOVIES          9999 non-null   object
#  1   YEAR            9355 non-null   object
#  2   GENRE           9919 non-null   object
#  3   RATING          8179 non-null   float64
#  4   ONE-LINE        9999 non-null   object
#  5   STARS           9999 non-null   object
#  6   VOTES           8179 non-null   object
#  7   RunTime         7041 non-null   float64
#  8   Gross           460 non-null    object
#  9   Extract_date    10147 non-null  object
#  10  owner_company   10147 non-null  object
#  11  nr_of_episodes  10147 non-null  int64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 951.4+ KB
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross', 'Extract_date', 'owner_company', 'nr_of_episodes'],
#       dtype='object')
